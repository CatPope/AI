# %% [markdown]
# ### 실습2
# 사용자가 입력한 질문에 맞는 캠핑장을 검색해서 추천하는 ChatGPT 어플리케이션을 작성하시오(힌트: 고캠핑 API) -> 10~30분 필요 (가이드에 따름)

# %%
# !pip install requests
# !pip install python-dotenv
# !pip install openai
# Out:
# Requirement already satisfied: requests in c:\program files\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python312\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python312\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python312\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python312\lib\site-packages (from requests) (2024.12.14)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\program files\python312\lib\site-packages (1.0.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai in c:\program files\python312\lib\site-packages (1.60.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\program files\python312\lib\site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\program files\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\program files\python312\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\program files\python312\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\program files\python312\lib\site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in c:\program files\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\program files\python312\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\program files\python312\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\program files\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\program files\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\program files\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\program files\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\program files\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\program files\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\ssrrf\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai 
import os
from dotenv import load_dotenv
import requests

# %%
now_path = os.getcwd()  # .ipynb 기준
dotenv_path = os.path.join(os.path.dirname(now_path), '.env')


load_dotenv(dotenv_path)

openai.api_key = os.getenv("OPENAI_API_KEY")
ServiceKey = os.getenv("ServiceKey")
# Out:
# True

# %%
ServiceKey
# Out:
# 'k5xqJOb%2B5Qe7JQIVBfuiQhsHXHN4hV8rZnKrAyT9KgW38iwwnFeNDUkguwLDH0fsxiatfK5aOExN3uFOYJ993Q%3D%3D'

# %%
keyword = input()
keyword
# Out:
# '계곡'

# %%
url = f"http://apis.data.go.kr/B551011/GoCamping/searchList?serviceKey={ServiceKey}&MobileOS=ETC&MobileApp=AppTest&keyword={keyword}&"
url
# Out:
# 'http://apis.data.go.kr/B551011/GoCamping/searchList?serviceKey=k5xqJOb%2B5Qe7JQIVBfuiQhsHXHN4hV8rZnKrAyT9KgW38iwwnFeNDUkguwLDH0fsxiatfK5aOExN3uFOYJ993Q%3D%3D&MobileOS=ETC&MobileApp=AppTest&keyword=계곡&'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
if response.status_code == 200:  # 요청 성공 시
    print(response.text)  # XML 또는 JSON 데이터 출력
else:
    print(f"Error: {response.status_code}")
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header>
#   <resultCode>0000</resultCode>
#   <resultMsg>OK</resultMsg>
# </header><body><items>
#   <item>
#     <contentId>100004</contentId>
#     <facltNm>뇌운계곡글램핑</facltNm>
#     <lineIntro></lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2021-3</trsagntNo>
#     <bizrno>225-02-29556</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>유현덕</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm>레저체험을 함께 즐길 수 있는 뇌운계곡 글램핑  뇌운계곡글램핑은 평창에 위치한 해발 600미터의 뇌운계곡에 있는 글램핑과 레저 체험을 함께 즐길 수 있는 캠핑장이다. 사이트는 총 7개인데, 4개는 글램핑 텐트, 3개는 몽골 텐트에 투명 돔 키친이 있다. 특히 몽골텐트는 천창이 투명하게 되어 있어 텐트 안에서도 하늘을 볼 수 있다. 텐트 내부의 집기들도 신경을 많이 써서 감성 캠핑을 즐기기 좋다. 또한 계곡에서의 래프팅, 패들 보드, 카약 강습은 물론 산악 오토바이, 숲속 서바이벌 게임 등 즐길 거리가 많다.</featureNm>
#     <induty>글램핑</induty>
#     <lctCl>산</lctCl>
#     <doNm>강원도</doNm>
#     <sigunguNm>평창군</sigunguNm>
#     <zipcode>25368</zipcode>
#     <addr1>강원 평창군 평창읍 뇌운계곡로 659-6</addr1>
#     <addr2></addr2>
#     <mapX>128.3820960</mapX>
#     <mapY>37.4156933</mapY>
#     <direction></direction>
#     <tel>033-332-0009</tel>
#     <homepage>https://pcglamping.modoo.at/</homepage>
#     <resveUrl></resveUrl>
#     <resveCl></resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>7</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty>침대,에어컨,냉장고,난방기구</glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2021-07-30</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,수상레저</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>Y</exprnProgrmAt>
#     <exprnProgrm>래프팅</exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>액티비티,여름물놀이</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/100004/thumb/thumb_720_0924x1f5rjPF1V1zMXPvW0Rh.jpg</firstImageUrl>
#     <createdtime>2023-01-16 16:48:53</createdtime>
#     <modifiedtime>2023-01-16 16:48:53</modifiedtime>
#   </item>
#   <item>
#     <contentId>100218</contentId>
#     <facltNm>김천맑은계곡 오토캠핑장</facltNm>
#     <lineIntro></lineIntro>
#     <intro>탁트인 뷰와 더불어 맑은 계곡이 있는 오토캠핑장입니다. 산과 냇가가 있는 공간에서 편리한 야영과 캠핑이 가능합니다.</intro>
#     <allar>3000</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2021-4</trsagntNo>
#     <bizrno>291-06-02154</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>김영금</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm>계곡과 맞닿아 있는 깔끔한 캠핑장  김천맑은계곡 오토캠핑장은 경북 김천시 부항면 대야리에 자리 잡았다. 김천시청을 기점으로 35km가량 떨어졌다. 자동차를 타고 부항로와 두산로를 번갈아 달리면 닿는다. 도착까지 걸리는 시간은 40분 안팎이다. 캠핑장은 계곡과 인접한 덕분에 여름철 물놀이를 즐기기 좋다. 파쇄석으로 이뤄진 오토캠핑 사이트 12면이 마련돼 있다. 사이트 크기는 가로 8m 세로 10m로 널찍하다. 카라반과 트레일러 동반 입장을 가능하며, 카라반의 경우 추가 요금이 있다. 주변에는 물한계곡이 있어 연계 여행이 수월하다.</featureNm>
#     <induty>일반야영장</induty>
#     <lctCl>숲</lctCl>
#     <doNm>경상북도</doNm>
#     <sigunguNm>김천시</sigunguNm>
#     <zipcode>39688</zipcode>
#     <addr1>경북 김천시 부항면 대야길 307</addr1>
#     <addr2></addr2>
#     <mapX>127.9184282</mapX>
#     <mapY>36.0192538</mapY>
#     <direction></direction>
#     <tel>054-433-1832</tel>
#     <homepage>https://blog.naver.com/kkcamping</homepage>
#     <resveUrl>https://booking.naver.com/booking/3/bizes/643565</resveUrl>
#     <resveCl>온라인예약대기</resveCl>
#     <manageNmpr>1</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>12</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>11</indvdlCaravSiteCo>
#     <sitedStnc>3</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>12</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>12</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2021-12-31</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>Y</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>2</toiletCo>
#     <swrmCo>2</swrmCo>
#     <wtrplCo>2</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>장작판매,온수,트렘폴린,놀이터,운동시설,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로,어린이놀이시설</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>12</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>여름물놀이</themaEnvrnCl>
#     <eqpmnLendCl>릴선,화로대</eqpmnLendCl>
#     <animalCmgCl>가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/100218/thumb/thumb_720_8553iOCJM4HG1xS54HkAaUZJ.jpg</firstImageUrl>
#     <createdtime>2023-01-16 16:49:15</createdtime>
#     <modifiedtime>2023-01-16 16:49:15</modifiedtime>
#   </item>
#   <item>
#     <contentId>100303</contentId>
#     <facltNm>영월 엄둔밸리 계곡캠핑장 </facltNm>
#     <lineIntro>원주 신림IC에서 20분 거리에 있는 계곡 캠핑장</lineIntro>
#     <intro>엄둔계곡 상류에 위치하여, 오염되지 않은 맑은 수질의 계곡이 흐르고 있어 어린이들의 천연수영장을 제공합니다. 다양한 크기의 청결한 펜션과  방갈로, 캠핑사이트를 함께 운영중입니다. 신림IC에서 20분거리에 위치하고 있으며, 조용하고 아름다운 산세속에서 도로 차소음 없이 지인과 함께 캠핑과 숙박을 같이 이용하시기에 편리한 구조입니다. </intro>
#     <allar>8264</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>제 2022-000001호</trsagntNo>
#     <bizrno>438-01-00804</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm>생수 따로 준비하지마세요!~ 천연 암반수(국가공인먹는물 수질검사인증)</featureNm>
#     <induty>일반야영장,자동차야영장,카라반</induty>
#     <lctCl>산,계곡</lctCl>
#     <doNm>강원도</doNm>
#     <sigunguNm>영월군</sigunguNm>
#     <zipcode>26201</zipcode>
#     <addr1>강원 영월군 무릉도원면 엄둔길 145</addr1>
#     <addr2>계곡펜션 계곡캠핑장 엄둔밸리</addr2>
#     <mapX>128.2350495</mapX>
#     <mapY>37.3097666</mapY>
#     <direction>강원도 영월군 무릉도원면 엄둔길145</direction>
#     <tel>010-3244-3968</tel>
#     <homepage>http://엄둔밸리.com/</homepage>
#     <resveUrl>https://www.camfit.co.kr/camp/623818516fa4ab001e00c448</resveUrl>
#     <resveCl>전화,온라인실시간예약,현장</resveCl>
#     <manageNmpr>4</manageNmpr>
#     <gnrlSiteCo>10</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>2</caravSiteCo>
#     <indvdlCaravSiteCo>3</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>9</siteMg1Width>
#     <siteMg2Width>8</siteMg2Width>
#     <siteMg3Width>8</siteMg3Width>
#     <siteMg1Vrticl>5</siteMg1Vrticl>
#     <siteMg2Vrticl>6</siteMg2Vrticl>
#     <siteMg3Vrticl>6</siteMg3Vrticl>
#     <siteMg1Co>1</siteMg1Co>
#     <siteMg2Co>1</siteMg2Co>
#     <siteMg3Co>7</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>10</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2022-03-08</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>Y</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>2</toiletCo>
#     <swrmCo>2</swrmCo>
#     <wtrplCo>2</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,트렘폴린,물놀이장,놀이터,산책로,운동장,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로,운동장,낚시,강/물놀이,청소년체험시설,농어촌체험시설,어린이놀이시설</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>20</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl>봄,여름,가을,겨울</tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2023-01-16 16:49:20</createdtime>
#     <modifiedtime>2024-01-10 06:30:09</modifiedtime>
#   </item>
#   <item>
#     <contentId>100474</contentId>
#     <facltNm>산중계곡캠핑장</facltNm>
#     <lineIntro></lineIntro>
#     <intro>계곡과 숲속에 자리한 오토캠핑장  산중계곡캠핑장은 경남 거창군 북상면에 자리 잡고 있다. 캠핑장은 숲속 사이트와 계곡 사이트로 구분된다. 파쇄석으로 이루어진 오토캠핑 사이트가 각각 19면과 20면이 마련되어 있다. 사이트 크기는 널찍해 대형 텐트를 설치하는 데 무리가 없다. 부대시설로는 한여름 무더위를 날리기 좋은 수영장이 있다. 주변에 덕유산국립공원이 있어 연계 여행에 나서기 수월하다.</intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo></trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장</induty>
#     <lctCl>계곡</lctCl>
#     <doNm>경상남도</doNm>
#     <sigunguNm>거창군</sigunguNm>
#     <zipcode>50102</zipcode>
#     <addr1>경남 거창군 북상면 송계사길 76</addr1>
#     <addr2></addr2>
#     <mapX>127.8053203</mapX>
#     <mapY>35.8297842</mapY>
#     <direction></direction>
#     <tel>0507-1370-5028</tel>
#     <homepage>http://sj-camping.com/</homepage>
#     <resveUrl>http://sj-camping.com/bbs/board.php?bo_table=yb_booking02</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>39</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>20</siteMg1Co>
#     <siteMg2Co>19</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>39</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2022-07-01</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>4</toiletCo>
#     <swrmCo>4</swrmCo>
#     <wtrplCo>2</wtrplCo>
#     <brazierCl></brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,물놀이장,놀이터,운동시설</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>20</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>봄꽃여행,여름물놀이,가을단풍명소</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2023-01-16 16:49:24</createdtime>
#     <modifiedtime>2024-04-20 06:30:35</modifiedtime>
#   </item>
#   <item>
#     <contentId>100532</contentId>
#     <facltNm>관악산 계곡 캠핑장</facltNm>
#     <lineIntro></lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo></trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>지자체</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장</induty>
#     <lctCl></lctCl>
#     <doNm>서울시</doNm>
#     <sigunguNm>관악구</sigunguNm>
#     <zipcode>08825</zipcode>
#     <addr1>서울특별시 관악구 신림동 205-1 관악산공원 내 </addr1>
#     <addr2></addr2>
#     <mapX>126.9481674</mapX>
#     <mapY>37.4620698</mapY>
#     <direction></direction>
#     <tel></tel>
#     <homepage></homepage>
#     <resveUrl></resveUrl>
#     <resveCl></resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2022-07-28</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl></sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2023-01-16 16:49:25</createdtime>
#     <modifiedtime>2023-01-16 16:49:25</modifiedtime>
#   </item>
#   <item>
#     <contentId>100675</contentId>
#     <facltNm>을수골 별빛계곡</facltNm>
#     <lineIntro>오지계곡 프라이빗 캠핑장</lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2022-7</trsagntNo>
#     <bizrno>792-19-01702</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>이준영</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장</induty>
#     <lctCl>계곡</lctCl>
#     <doNm>강원도</doNm>
#     <sigunguNm>홍천군</sigunguNm>
#     <zipcode>25170</zipcode>
#     <addr1>강원 홍천군 내면 을수길 127</addr1>
#     <addr2></addr2>
#     <mapX>128.4577053</mapX>
#     <mapY>37.8178687</mapY>
#     <direction></direction>
#     <tel></tel>
#     <homepage>https://eulsugolbyeolbit.modoo.at/</homepage>
#     <resveUrl></resveUrl>
#     <resveCl></resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2022-10-31</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl></sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/100675/thumb/thumb_720_8329AzRfBwavTjDSc1lsKcB8.jpg</firstImageUrl>
#     <createdtime>2023-01-16 16:49:26</createdtime>
#     <modifiedtime>2023-09-12 09:20:05</modifiedtime>
#   </item>
#   <item>
#     <contentId>100682</contentId>
#     <facltNm>양평힐링계곡 오토캠핑장</facltNm>
#     <lineIntro></lineIntro>
#     <intro>양평힐링계곡오토캠핑장은 서울에서 가까운 양평군 서종면에 위치한 신생 캠핑장으로 일체형 비데와 쾌적한 샤워시설 등 깨끗한 편의시설을 갖추었으며, 맑은 계곡과 총총한 별을 볼 수 있는 아늑하고 분위기 좋은 캠핑장 입니다.</intro>
#     <allar>2998</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2022-3</trsagntNo>
#     <bizrno>844-42-00701</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>강유현</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>자동차야영장</induty>
#     <lctCl>숲</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>양평군</sigunguNm>
#     <zipcode>12501</zipcode>
#     <addr1>경기 양평군 서종면 중미산로 772-27</addr1>
#     <addr2></addr2>
#     <mapX>127.4230682</mapX>
#     <mapY>37.6010371</mapY>
#     <direction></direction>
#     <tel>031-772-9999</tel>
#     <homepage>healingvalley.campingt.me</homepage>
#     <resveUrl>https://booking.naver.com/booking/3/bizes/791312</resveUrl>
#     <resveCl></resveCl>
#     <manageNmpr>3</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>27</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2022-11-03</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>3</toiletCo>
#     <swrmCo>7</swrmCo>
#     <wtrplCo>12</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,물놀이장,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>23</extshrCo>
#     <frprvtWrppCo>5</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>가능(소형견)</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/100682/thumb/thumb_720_2061M8xPf2Z4yf4yu0JXAMjm.jpg</firstImageUrl>
#     <createdtime>2023-01-16 16:49:27</createdtime>
#     <modifiedtime>2023-01-16 16:49:27</modifiedtime>
#   </item>
#   <item>
#     <contentId>100973</contentId>
#     <facltNm>유명산 계곡 캠핑장</facltNm>
#     <lineIntro>유명산 자락 어비계곡 안쪽에 위치한 팬션&amp;캠핑장</lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo></trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장,카라반</induty>
#     <lctCl>산</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>가평군</sigunguNm>
#     <zipcode>12473</zipcode>
#     <addr1>경기 가평군 설악면 어비산길 201-41</addr1>
#     <addr2></addr2>
#     <mapX>127.5137288</mapX>
#     <mapY>37.5918631</mapY>
#     <direction></direction>
#     <tel></tel>
#     <homepage></homepage>
#     <resveUrl>https://pf.kakao.com/_SNQAG</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>6</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>2</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>6</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty>침대,TV,에어컨,냉장고,유무선인터넷,난방기구,취사도구</caravInnerFclty>
#     <prmisnDe>2023-06-19</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl></sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2023-07-04 06:30:02</createdtime>
#     <modifiedtime>2024-12-24 06:30:01</modifiedtime>
#   </item>
#   <item>
#     <contentId>100999</contentId>
#     <facltNm>달빛 계곡 캠핑장</facltNm>
#     <lineIntro></lineIntro>
#     <intro>청정한 공기와 산을 둘러싸고 있어 계절마다 변화하는 산의 모습을 볼수있으며, 반짝반짝 별이가득한 밤하늘을 느낄수있는 캠핑장입니다.</intro>
#     <allar>5000</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2023-1</trsagntNo>
#     <bizrno>264-06-02657</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>윤형수</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>자동차야영장</induty>
#     <lctCl></lctCl>
#     <doNm>전라남도</doNm>
#     <sigunguNm>장흥군</sigunguNm>
#     <zipcode>59300</zipcode>
#     <addr1>전남 장흥군 유치면 봉덕신덕길 371</addr1>
#     <addr2></addr2>
#     <mapX>126.8667308</mapX>
#     <mapY>34.8300302</mapY>
#     <direction></direction>
#     <tel></tel>
#     <homepage></homepage>
#     <resveUrl></resveUrl>
#     <resveCl></resveCl>
#     <manageNmpr>1</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>12</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2023-07-14</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>3</toiletCo>
#     <swrmCo>3</swrmCo>
#     <wtrplCo>3</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,물놀이장,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,강/물놀이,농어촌체험시설</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>7</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>3</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2023-07-22 06:30:06</createdtime>
#     <modifiedtime>2023-07-26 06:30:07</modifiedtime>
#   </item>
#   <item>
#     <contentId>101091</contentId>
#     <facltNm>금천계곡 야영장</facltNm>
#     <lineIntro></lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo></trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>자동차야영장</induty>
#     <lctCl>계곡</lctCl>
#     <doNm>전라남도</doNm>
#     <sigunguNm>광양시</sigunguNm>
#     <zipcode>57708</zipcode>
#     <addr1>전남 광양시 다압면 대청길 15</addr1>
#     <addr2></addr2>
#     <mapX>127.652178</mapX>
#     <mapY>35.1569293</mapY>
#     <direction></direction>
#     <tel>010-7930-0071</tel>
#     <homepage></homepage>
#     <resveUrl></resveUrl>
#     <resveCl></resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2023-08-31</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl></sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2023-09-05 06:30:07</createdtime>
#     <modifiedtime>2023-11-02 06:30:07</modifiedtime>
#   </item>
# </items>  <numOfRows>10</numOfRows>
#   <pageNo>1</pageNo>
#   <totalCount>71</totalCount>
# </body></response>
