# %%
# !pip install python-dotenv openai
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().system('pip install python-dotenv openai')
#
# Cell In[4], line 1
# ----> 1 get_ipython().system('pip install python-dotenv openai')
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~/.local/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/.local/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
from dotenv import load_dotenv

load_dotenv("/home/ubuntu/work/edu-src-all/.env")
#load_dotenv()
# Out:
# True

# %%
# Completion mode, 지시와 명령을 하나의 prompt로 전달
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")
# 텍스트 생성 요청을 보냅니다.
response = openai.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt = "다음을 일본어로 번역하세요: 안녕하세요? 오늘 날씨가 참 좋군요!",
    max_tokens=256,  # 생성된 텍스트의 최대 길이를 설정합니다.
)

print(response.choices[0].text)
# Out:
# こんにちは？今日の天気は本当にいいですね！

# %%
# Completion mode, 문장을 이어서 완성하게 함
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")
# 텍스트 생성 요청을 보냅니다.
response = openai.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt="근육이 커지려면",
    max_tokens=256,  # 생성된 텍스트의 최대 길이를 설정합니다.
)

# 생성된 텍스트를 출력합니다.
print(response.choices[0].text)
# Out:
#  식사량 보다 단백질 보충을 많이 해야 한다지.그럼 근육을 키우기 위해서는 얼만큼 단백질 섭취량을 많이 해야하나요
#
# 한국 병원 알마나찌 다이어트
#
# 한국 병원 알마나찌 다이어트는 1일에 대략 1.2g~2.2g의 단백질 섭취량을 권장합니다. 하지만 근육을 키우기 위해서는 개인의 체중, 활동 수준 등 개인의 신체 상태에 따라 달라질 수 있기 때문에 개인의 몸상태에 맞춰 정확한 단백질 섭취량을 조절하는 것이 중요합니다. 근육을 키우기 위해서는 일반적으로 체

# %%
print(response)
# Out:
# Completion(id='cmpl-CV8bbE2fxWZjAl59M8It0Wr5VMjQ9', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text=' 운동을 해야겠지)")\n      codec.decodeFromString("problematicCode")\n    }\n  }\n\n  "LengthCodecTest" should "test Successfully writing an integer to JSON and retrieving it with the right type" in {\n    val l1 = 10L\n    val encoder = JsonFormat.genericBinaryEncoder(serializer)\n    val schema = encoder.encodingSchema\n    val lengthEncoder = LengthCodec(schema)\n    val result = new GenericRecord(schema)\n    lengthEncoder.encode(l1, result, encoder)\n\n    val decoder = JsonFormat.genericBinaryDecoder(serializer, BinaryEncoder.encode(s"${result}".getBytes))\n    val lenDecoder = LengthCodec(result.getSchema)\n    val json = lenDecoder.decode(result, decoder)\n    assert(l1 == json)\n    withClue(s"${assertMsgHeader}LengthCodecTest:test Successfully writing an integer to JSON and retrieving it with the right type: decoded number is wrong: ") {\n      codec.decodeFromByteArray(BinaryEncoder.encode(s"${result}".getBytes))\n    }\n  }\n\n  it should "test the function throws a non-default length" in {\n    val data: Seq[Byte] = Seq(1, 2, 3, 4, 5)\n    val deletedColumnListLength: Int =\n     ')], created=1761537283, model='gpt-3.5-turbo-instruct:20230824-v2', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=256, prompt_tokens=11, total_tokens=267, completion_tokens_details=None, prompt_tokens_details=None))

# %%
# 표준적인 Chat completion mode

import openai

res = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[{"role": "user", "content": "다음을 일본어로 번역하세요: 안녕하세요? 오늘 날씨가 참 좋군요!"}]
)
print(res.choices[0].message.content)
# Out:
# 안녕하세요? 오늘 날씨가 참 좋군요!는 일본어로 다음과 같이 번역됩니다:
#
# こんにちは！今日は天気がとても良いですね！

# %%
print(res)
# Out:
# ChatCompletion(id='chatcmpl-CV8beXbXQSMFn0gqyhnkTm283E6H9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='안녕하세요? 오늘 날씨가 참 좋군요!는 일본어로 다음과 같이 번역됩니다:\n\nこんにちは！今日は天気がとても良いですね！', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1761537286, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_560af6e559', usage=CompletionUsage(completion_tokens=35, prompt_tokens=28, total_tokens=63, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
