# %%
# !pip install -U gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gradio==4.4.1
#   Downloading gradio-4.4.1-py3-none-any.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 3.1 MB/s eta 0:00:0000:0100:01
# Collecting ffmpy
#   Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Collecting pillow<11.0,>=8.0
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 3.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: markupsafe~=2.0 in /usr/lib/python3/dist-packages (from gradio==4.4.1) (2.0.1)
# Collecting uvicorn>=0.14.0
#   Using cached uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (0.21.0)
# Collecting matplotlib~=3.0
#   Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting fastapi
#   Using cached fastapi-0.128.0-py3-none-any.whl (103 kB)
# Requirement already satisfied: jinja2<4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (3.1.6)
# Requirement already satisfied: typing-extensions~=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (4.15.0)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting importlib-resources<7.0,>=1.3
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: orjson~=3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (3.11.5)
# Collecting tomlkit==0.12.0
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pydantic>=2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (2.12.5)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/lib/python3/dist-packages (from gradio==4.4.1) (5.4.1)
# Collecting altair<6.0,>=4.2.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting semantic-version~=2.0
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting aiofiles<24.0,>=22.0
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: httpx in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (0.28.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (2.3.3)
# Requirement already satisfied: packaging in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (24.2)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (1.2.3)
# Collecting gradio-client==0.7.0
#   Downloading gradio_client-0.7.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 KB 4.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy~=1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (1.26.4)
# Requirement already satisfied: requests~=2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio==4.4.1) (2.32.5)
# Collecting python-multipart
#   Using cached python_multipart-0.0.21-py3-none-any.whl (24 kB)
# Collecting websockets<12.0,>=10.0
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 KB 3.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: fsspec in /home/ubuntu/.local/lib/python3.10/site-packages (from gradio-client==0.7.0->gradio==4.4.1) (2025.10.0)
# Collecting narwhals>=1.14.2
#   Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.9/432.9 KB 4.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jsonschema>=3.0 in /usr/lib/python3/dist-packages (from altair<6.0,>=4.2.0->gradio==4.4.1) (3.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio==4.4.1) (1.2.0)
# Requirement already satisfied: shellingham in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio==4.4.1) (1.5.4)
# Requirement already satisfied: filelock in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio==4.4.1) (3.20.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio==4.4.1) (4.67.1)
# Requirement already satisfied: typer-slim in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio==4.4.1) (0.21.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx->gradio==4.4.1) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->gradio==4.4.1) (1.0.9)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->gradio==4.4.1) (4.12.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx->gradio==4.4.1) (3.3)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->gradio==4.4.1) (0.16.0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.7 MB/s eta 0:00:00a 0:00:010m
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.8/121.8 KB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.4.1) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 2.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<3.0,>=1.0->gradio==4.4.1) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.4.1) (2025.3)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.4.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.4.1) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.4.1) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests~=2.0->gradio==4.4.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests~=2.0->gradio==4.4.1) (1.26.5)
# WARNING: typer 0.21.0 does not provide the extra 'all'
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.4.1) (8.0.3)
# Requirement already satisfied: rich>=10.11.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.4.1) (14.2.0)
# Collecting starlette<0.51.0,>=0.40.0
#   Using cached starlette-0.50.0-py3-none-any.whl (74 kB)
# Collecting annotated-doc>=0.0.2
#   Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.4.1) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.4.1) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.4.1) (4.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx->gradio==4.4.1) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.4.1) (0.1.2)
# Installing collected packages: pydub, websockets, uvicorn, tomlkit, semantic-version, python-multipart, pyparsing, pillow, narwhals, kiwisolver, importlib-resources, fonttools, ffmpy, cycler, contourpy, annotated-doc, aiofiles, matplotlib, altair, starlette, fastapi, gradio-client, gradio
#   Attempting uninstall: pillow
#     Found existing installation: pillow 12.0.0
#     Uninstalling pillow-12.0.0:
#       Successfully uninstalled pillow-12.0.0
# Successfully installed aiofiles-23.2.1 altair-5.5.0 annotated-doc-0.0.4 contourpy-1.3.2 cycler-0.12.1 fastapi-0.128.0 ffmpy-1.0.0 fonttools-4.61.1 gradio-4.4.1 gradio-client-0.7.0 importlib-resources-6.5.2 kiwisolver-1.4.9 matplotlib-3.10.8 narwhals-2.15.0 pillow-10.4.0 pydub-0.25.1 pyparsing-3.3.1 python-multipart-0.0.21 semantic-version-2.10.0 starlette-0.50.0 tomlkit-0.12.0 uvicorn-0.40.0 websockets-11.0.3

# %%
import gradio as gr

# 인터페이스에서 이벤트가 발생되면 실행되는 함수
def greet(name):
    return "안녕하세요 " + name + "씨!"

# inputs로 TextBox 타입의 컴포넌트, outputs로 TextBox 타입의 컴포넌트가 하나씩 적용
demo = gr.Interface(fn=greet, inputs="text", outputs="text")

# 서버 어플리케이션은 모든 네트워크 인터페이스에 바인딩한다
demo.launch(server_name='0.0.0.0')
# Out:
# Running on local URL:  http://0.0.0.0:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def greet(name):
    return "안녕하세요 " + name + "씨!"

demo = gr.Interface(
    fn=greet,
    inputs=gr.Textbox(lines=2, placeholder="여기에 이름을 쓰세요."), # TextBox의 속성을 변경
    outputs="text",
)

demo.launch(server_name='0.0.0.0')
# Out:
# Running on local URL:  http://0.0.0.0:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

# 여기서의 input이 인터페이스의 input(순서대로)
def greet(name, is_morning, temperature):
    salutation = "좋은 아침입니다" if is_morning else "좋은 저녁입니다"
    greeting = f"{salutation} {name}씨. 오늘은 섭씨 {temperature}도입니다."
    fahrenheit = (temperature - 32) * 5 / 9
    return greeting, (temperature * 9 / 5) + 32 
    
# 리턴은 인터페이스의 output(순서대로)

demo = gr.Interface(
    fn=greet,
    inputs=["text", "checkbox", gr.Slider(0, 100)],
    outputs=["text", "number"],
)

demo.launch(server_name='0.0.0.0', share=True)
# Out:
# Running on local URL:  http://0.0.0.0:7862
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://d1a5cae0825f49b7f1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d1a5cae0825f49b7f1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import numpy as np
import gradio as gr

def sepia(input_img):
    sepia_filter = np.array([
        [0.393, 0.769, 0.189], 
        [0.349, 0.686, 0.168], 
        [0.272, 0.534, 0.131]
    ])
    sepia_img = input_img.dot(sepia_filter.T)
    sepia_img /= sepia_img.max()
    return sepia_img

# gr.Image는 이미지만 전문으로 입력 또는 출력하는 컴포넌트
demo = gr.Interface(sepia, gr.Image(width=200, height=200), "image")
demo.launch(server_name='0.0.0.0')
# Out:
# Running on local URL:  http://0.0.0.0:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import random
import gradio as gr

def random_response(message, history):
    return random.choice(["네", "아니오"])

demo = gr.ChatInterface(random_response)

demo.launch(server_name='0.0.0.0')
# Out:
# Running on local URL:  http://0.0.0.0:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def greet(name):
    return "안녕하세요 " + name + "씨!"

with gr.Blocks() as demo:
    name = gr.Textbox(label="Name")
    output = gr.Textbox(label="Output Box")
    greet_btn = gr.Button("Greet")
    greet_btn.click(fn=greet, inputs=name, outputs=output, api_name="greet")

demo.launch(server_name='0.0.0.0')
# Out:
# Running on local URL:  http://0.0.0.0:7865
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import numpy as np
import gradio as gr


def flip_text(x):
    return x[::-1]


def flip_image(x):
    return np.fliplr(x)


with gr.Blocks() as demo:
    gr.Markdown("## Flip text or image files using this demo.")
    with gr.Tab("Flip Text"):
        text_input = gr.Textbox()
        text_output = gr.Textbox()
        text_button = gr.Button("Flip")
    with gr.Tab("Flip Image"):
        with gr.Row():
            image_input = gr.Image()
            image_output = gr.Image()
        image_button = gr.Button("Flip")

    with gr.Accordion("Open for More!"):
        gr.Markdown("Look at me...")

    text_button.click(flip_text, inputs=text_input, outputs=text_output)
    image_button.click(flip_image, inputs=image_input, outputs=image_output)

demo.launch(server_name='0.0.0.0')
# Out:
# Running on local URL:  http://0.0.0.0:7866
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def calculator(num1, operation, num2):
    if operation == "add":
        return num1 + num2
    elif operation == "subtract":
        return num1 - num2
    elif operation == "multiply":
        return num1 * num2
    elif operation == "divide":
        if num2 == 0:
            raise gr.Error("Cannot divide by zero!")
        return num1 / num2

# 함수, inputs, outputs, 그외 example도 간단하게 추가 가능

demo = gr.Interface(
    calculator,
    [
        "number", 
        gr.Radio(["add", "subtract", "multiply", "divide"]),
        "number"
    ],
    "number",
    examples=[
        [5, "add", 3],
        [4, "divide", 2],
        [-4, "multiply", 2.5],
        [0, "subtract", 1.2],
    ],
    title="Toy Calculator",
    description="Here's a sample toy calculator. Allows you to calculate things like $2+2=4$",
)

demo.launch(server_name='0.0.0.0')
# Out:
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://0.0.0.0:7867
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 4.4.1, however version 4.44.1 is available, please upgrade.
# --------
