# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/ubuntu/.local/lib/python3.10/site-packages (1.59.8)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (2.10.5)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (0.27.2)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->openai) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)

# %%
import os

os.environ["OPENAI_DEFAULT_MODEL"] = "gpt-4o-mini"

# %%
import requests
import os

searching = '판교동 레스토랑'
kakao_api_key = os.getenv("KAKAO_API_KEY")
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": f"KakaoAK {kakao_api_key}"
}
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '경기 성남시 분당구 판교동 614',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '21484277',
#    'phone': '031-8016-1865',
#    'place_name': '뚜에이오',
#    'place_url': 'http://place.map.kakao.com/21484277',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24-2',
#    'x': '127.08878251993',
#    'y': '37.3913068226745'},
#   {'address_name': '경기 성남시 분당구 판교동 614-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '14589499',
#    'phone': '',
#    'place_name': '라비떼',
#    'place_url': 'http://place.map.kakao.com/14589499',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 16',
#    'x': '127.08955522531403',
#    'y': '37.39155131811151'},
#   {'address_name': '경기 성남시 분당구 판교동 599',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '16065056',
#    'phone': '031-8016-6262',
#    'place_name': '샤슬릭',
#    'place_url': 'http://place.map.kakao.com/16065056',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 45',
#    'x': '127.09300276802902',
#    'y': '37.38964029121598'},
#   {'address_name': '경기 성남시 분당구 판교동 600-5',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '708092398',
#    'phone': '010-3005-9541',
#    'place_name': '오스테리아 워모잡',
#    'place_url': 'http://place.map.kakao.com/708092398',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 40-1',
#    'x': '127.093826013936',
#    'y': '37.3896666715851'},
#   {'address_name': '경기 성남시 분당구 판교동 617-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '27300858',
#    'phone': '031-8016-8074',
#    'place_name': '라스토리아1001',
#    'place_url': 'http://place.map.kakao.com/27300858',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24',
#    'x': '127.088863533106',
#    'y': '37.3910580796215'},
#   {'address_name': '경기 성남시 분당구 판교동 610',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '2092406855',
#    'phone': '031-701-0345',
#    'place_name': '피제리아 비니스',
#    'place_url': 'http://place.map.kakao.com/2092406855',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 70',
#    'x': '127.091160140249',
#    'y': '37.3908085502984'},
#   {'address_name': '경기 성남시 분당구 판교동 497',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 도미노피자',
#    'distance': '',
#    'id': '18154958',
#    'phone': '031-8017-9096',
#    'place_name': '도미노피자 판교점',
#    'place_url': 'http://place.map.kakao.com/18154958',
#    'road_address_name': '경기 성남시 분당구 서판교로 160',
#    'x': '127.09485899977564',
#    'y': '37.400209605227566'},
#   {'address_name': '경기 성남시 분당구 판교동 618-7',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 멕시칸,브라질',
#    'distance': '',
#    'id': '442176392',
#    'phone': '031-703-0255',
#    'place_name': '갓잇 서판교점',
#    'place_url': 'http://place.map.kakao.com/442176392',
#    'road_address_name': '경기 성남시 분당구 판교공원로5길 24',
#    'x': '127.089829598053',
#    'y': '37.3905725995806'},
#   {'address_name': '경기 성남시 분당구 판교동 616-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자',
#    'distance': '',
#    'id': '1363058678',
#    'phone': '',
#    'place_name': '피제리아살레르노 서판교점',
#    'place_url': 'http://place.map.kakao.com/1363058678',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 35',
#    'x': '127.090161010775',
#    'y': '37.3910255616983'},
#   {'address_name': '경기 성남시 분당구 판교동 567-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1813415551',
#    'phone': '031-8016-0168',
#    'place_name': '플랩잭팬트리 본점',
#    'place_url': 'http://place.map.kakao.com/1813415551',
#    'road_address_name': '경기 성남시 분당구 서판교로44번길 17-11',
#    'x': '127.099584320006',
#    'y': '37.3916234885259'},
#   {'address_name': '경기 성남시 분당구 판교동 602-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '1793834083',
#    'phone': '031-781-0122',
#    'place_name': '에이치이에이',
#    'place_url': 'http://place.map.kakao.com/1793834083',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 67',
#    'x': '127.091385646215',
#    'y': '37.3905245541454'},
#   {'address_name': '경기 성남시 분당구 판교동 512',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 파파존스',
#    'distance': '',
#    'id': '27334535',
#    'phone': '031-709-9492',
#    'place_name': '파파존스 판교점',
#    'place_url': 'http://place.map.kakao.com/27334535',
#    'road_address_name': '경기 성남시 분당구 서판교로 154',
#    'x': '127.09521543438433',
#    'y': '37.39985071235571'},
#   {'address_name': '경기 성남시 분당구 판교동 602-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '817384546',
#    'phone': '031-778-6463',
#    'place_name': '칠리로29 판교점',
#    'place_url': 'http://place.map.kakao.com/817384546',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 69',
#    'x': '127.09122079999591',
#    'y': '37.39054450391926'},
#   {'address_name': '경기 성남시 분당구 판교동 614-9',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1992463433',
#    'phone': '031-704-1124',
#    'place_name': '일로이 키친',
#    'place_url': 'http://place.map.kakao.com/1992463433',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 10',
#    'x': '127.09016037466169',
#    'y': '37.3914373294357'},
#   {'address_name': '경기 성남시 분당구 판교동 598-3',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '1564711667',
#    'phone': '',
#    'place_name': '라빌란치아 이탈리안음식전문점',
#    'place_url': 'http://place.map.kakao.com/1564711667',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 49',
#    'x': '127.092529742635',
#    'y': '37.3897415768359'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '레스토랑',
#    'region': [],
#    'selected_region': '경기 성남시 분당구 판교동'},
#   'total_count': 270}}

# %%
#question = "판교동에 있는 레스토랑을 두세개 추천해줘."
question = "강남구에 있는 해물전문점을 두세개 추천해줘."

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """다음 질문에서 지명 하나와 가장 중요한 키워드 하나를 추출해서 하나로 붙여줘.
원하는 형식:
<place>:<keyword>
"""
    },
    {
      "role": "user",
      "content": question
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 강남구:해물전문점

# %%
array = response.choices[0].message.content.split(":")
location = array[0]
keyword = array[1]

location, keyword
# Out:
# ('강남구', '해물전문점')

# %%
import requests

searching = f'{location} {keyword}'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": f"KakaoAK {kakao_api_key}"
}
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '서울 강남구 신사동 663',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선',
#    'distance': '',
#    'id': '25046575',
#    'phone': '02-514-8008',
#    'place_name': '뱃고동',
#    'place_url': 'http://place.map.kakao.com/25046575',
#    'road_address_name': '서울 강남구 언주로172길 54',
#    'x': '127.03804340336',
#    'y': '37.5268498895352'},
#   {'address_name': '서울 강남구 논현동 98-8',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 장어',
#    'distance': '',
#    'id': '1257441291',
#    'phone': '02-3448-9991',
#    'place_name': '영동장어',
#    'place_url': 'http://place.map.kakao.com/1257441291',
#    'road_address_name': '서울 강남구 언주로148길 8',
#    'x': '127.035338774027',
#    'y': '37.5203166598331'},
#   {'address_name': '서울 강남구 논현동 115-4',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 조개',
#    'distance': '',
#    'id': '16063439',
#    'phone': '02-516-4787',
#    'place_name': '맛짱조개',
#    'place_url': 'http://place.map.kakao.com/16063439',
#    'road_address_name': '서울 강남구 언주로134길 18',
#    'x': '127.03701110873816',
#    'y': '37.51658058812537'},
#   {'address_name': '서울 강남구 역삼동 619-30',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 회',
#    'distance': '',
#    'id': '27254228',
#    'phone': '02-501-5534',
#    'place_name': '자매수산 1호점',
#    'place_url': 'http://place.map.kakao.com/27254228',
#    'road_address_name': '서울 강남구 봉은사로18길 90',
#    'x': '127.0277117906',
#    'y': '37.5008389787037'},
#   {'address_name': '서울 강남구 역삼동 828-52',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 회',
#    'distance': '',
#    'id': '8652100',
#    'phone': '02-556-3677',
#    'place_name': '고래불 역삼본점',
#    'place_url': 'http://place.map.kakao.com/8652100',
#    'road_address_name': '서울 강남구 논현로79길 62',
#    'x': '127.03396137926865',
#    'y': '37.49625663127778'},
#   {'address_name': '서울 강남구 논현동 261',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 게,대게',
#    'distance': '',
#    'id': '1777540958',
#    'phone': '02-547-7998',
#    'place_name': '크래버대게나라 강남점',
#    'place_url': 'http://place.map.kakao.com/1777540958',
#    'road_address_name': '서울 강남구 언주로 620',
#    'x': '127.036257660784',
#    'y': '37.5116883705501'},
#   {'address_name': '서울 강남구 신사동 576-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선',
#    'distance': '',
#    'id': '699742929',
#    'phone': '02-516-5050',
#    'place_name': '청초수물회섭국 강남점',
#    'place_url': 'http://place.map.kakao.com/699742929',
#    'road_address_name': '서울 강남구 압구정로28길 24',
#    'x': '127.02747863210529',
#    'y': '37.524998557729816'},
#   {'address_name': '서울 강남구 신사동 627-13',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 복어',
#    'distance': '',
#    'id': '8203089',
#    'phone': '02-542-5482',
#    'place_name': '금수복국 압구정점',
#    'place_url': 'http://place.map.kakao.com/8203089',
#    'road_address_name': '서울 강남구 언주로 821',
#    'x': '127.03278366514495',
#    'y': '37.52353758045752'},
#   {'address_name': '서울 강남구 역삼동 809-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 추어',
#    'distance': '',
#    'id': '21332166',
#    'phone': '02-557-8647',
#    'place_name': '원조원주추어탕 강남본점',
#    'place_url': 'http://place.map.kakao.com/21332166',
#    'road_address_name': '서울 강남구 강남대로110길 6',
#    'x': '127.02547367978',
#    'y': '37.5040434588993'},
#   {'address_name': '서울 강남구 대치동 894-5',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선',
#    'distance': '',
#    'id': '10165519',
#    'phone': '02-562-9292',
#    'place_name': '남도사계고운님',
#    'place_url': 'http://place.map.kakao.com/10165519',
#    'road_address_name': '서울 강남구 삼성로81길 22',
#    'x': '127.05589211506707',
#    'y': '37.50432851268551'},
#   {'address_name': '서울 강남구 역삼동 736-19',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 회',
#    'distance': '',
#    'id': '21155020',
#    'phone': '02-566-3563',
#    'place_name': '강남보물섬',
#    'place_url': 'http://place.map.kakao.com/21155020',
#    'road_address_name': '서울 강남구 테헤란로20길 11-1',
#    'x': '127.034713541288',
#    'y': '37.4990315124996'},
#   {'address_name': '서울 강남구 논현동 16-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 아구',
#    'distance': '',
#    'id': '25040567',
#    'phone': '02-546-9947',
#    'place_name': '부산아구',
#    'place_url': 'http://place.map.kakao.com/25040567',
#    'road_address_name': '서울 강남구 강남대로150길 10',
#    'x': '127.020717859302',
#    'y': '37.5157934886313'},
#   {'address_name': '서울 강남구 역삼동 683-26',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 추어',
#    'distance': '',
#    'id': '27187696',
#    'phone': '02-552-8889',
#    'place_name': '인평일등추어탕',
#    'place_url': 'http://place.map.kakao.com/27187696',
#    'road_address_name': '서울 강남구 선릉로 555',
#    'x': '127.044851582109',
#    'y': '37.5079624691581'},
#   {'address_name': '서울 강남구 역삼동 817-34',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선',
#    'distance': '',
#    'id': '11463001',
#    'phone': '02-508-4629',
#    'place_name': '알부자 강남본점',
#    'place_url': 'http://place.map.kakao.com/11463001',
#    'road_address_name': '서울 강남구 강남대로98길 14',
#    'x': '127.027820307026',
#    'y': '37.5007020002887'},
#   {'address_name': '서울 강남구 역삼동 696-31',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 한식 > 해물,생선 > 회',
#    'distance': '',
#    'id': '27256514',
#    'phone': '02-562-9277',
#    'place_name': '통영집',
#    'place_url': 'http://place.map.kakao.com/27256514',
#    'road_address_name': '서울 강남구 선릉로 527',
#    'x': '127.047402228858',
#    'y': '37.5064982411203'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '해물', 'region': [], 'selected_region': '서울 강남구'},
#   'total_count': 1693}}

# %%
import json

context = ''
i = 1;
for place in places['documents']:
    context = context + f"{i}) {place['place_name']}, {place['address_name']}, {place['category_name']} "
    i = i + 1
context
# Out:
# '1) 뱃고동, 서울 강남구 신사동 663, 음식점 > 한식 > 해물,생선 2) 영동장어, 서울 강남구 논현동 98-8, 음식점 > 한식 > 해물,생선 > 장어 3) 맛짱조개, 서울 강남구 논현동 115-4, 음식점 > 한식 > 해물,생선 > 조개 4) 자매수산 1호점, 서울 강남구 역삼동 619-30, 음식점 > 한식 > 해물,생선 > 회 5) 고래불 역삼본점, 서울 강남구 역삼동 828-52, 음식점 > 한식 > 해물,생선 > 회 6) 크래버대게나라 강남점, 서울 강남구 논현동 261, 음식점 > 한식 > 해물,생선 > 게,대게 7) 청초수물회섭국 강남점, 서울 강남구 신사동 576-6, 음식점 > 한식 > 해물,생선 8) 금수복국 압구정점, 서울 강남구 신사동 627-13, 음식점 > 한식 > 해물,생선 > 복어 9) 원조원주추어탕 강남본점, 서울 강남구 역삼동 809-1, 음식점 > 한식 > 해물,생선 > 추어 10) 남도사계고운님, 서울 강남구 대치동 894-5, 음식점 > 한식 > 해물,생선 11) 강남보물섬, 서울 강남구 역삼동 736-19, 음식점 > 한식 > 해물,생선 > 회 12) 부산아구, 서울 강남구 논현동 16-1, 음식점 > 한식 > 해물,생선 > 아구 13) 인평일등추어탕, 서울 강남구 역삼동 683-26, 음식점 > 한식 > 해물,생선 > 추어 14) 알부자 강남본점, 서울 강남구 역삼동 817-34, 음식점 > 한식 > 해물,생선 15) 통영집, 서울 강남구 역삼동 696-31, 음식점 > 한식 > 해물,생선 > 회 '

# %%
import os
import openai
import json

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": f"주어진 문단을 보고 다음 질문에 답해줘: {question}"
    },
    {
      "role": "user",
      "content": context
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 강남구에 있는 해물전문점으로 다음 세 곳을 추천합니다:
#
# 1. **뱃고동** - 서울 강남구 신사동 663, 해물과 생선 요리를 전문으로 하는 한식 음식점입니다.
# 2. **크래버대게나라 강남점** - 서울 강남구 논현동 261, 게와 대게 요리를 전문으로 하는 한식 음식점입니다.
# 3. **자매수산 1호점** - 서울 강남구 역삼동 619-30, 회를 전문으로 하는 한식 음식점입니다.
#
# 이 세 곳은 다양한 해물 요리를 즐길 수 있는 좋은 선택입니다.
