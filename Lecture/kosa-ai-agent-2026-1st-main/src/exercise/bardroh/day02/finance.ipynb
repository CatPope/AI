# %%
# !pip install pykrx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pykrx
#   Downloading pykrx-1.0.51-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 33.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from pykrx) (2.25.1)
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 80.8 MB/s eta 0:00:0000:0100:01
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 24.6 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 82.7 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 75.9 MB/s eta 0:00:0000:0100:01
# Collecting datetime
#   Downloading datetime-6.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 KB 11.3 MB/s eta 0:00:00
# Collecting multipledispatch
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Collecting deprecated
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pytz in /usr/lib/python3/dist-packages (from datetime->pykrx) (2022.1)
# Requirement already satisfied: zope.interface in /usr/lib/python3/dist-packages (from datetime->pykrx) (5.4.0)
# Collecting wrapt<3,>=1.10
#   Downloading wrapt-2.0.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 KB 23.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib->pykrx) (2.9.0.post0)
# Collecting pillow>=8
#   Downloading pillow-12.1.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 89.6 MB/s eta 0:00:00:00:0100:01
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.8/121.8 KB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib->pykrx) (25.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 76.8 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 90.6 MB/s eta 0:00:00ta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 KB 82.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->pykrx) (1.16.0)
# Installing collected packages: multipledispatch, xlrd, wrapt, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, datetime, cycler, pandas, deprecated, contourpy, matplotlib, pykrx
# Successfully installed contourpy-1.3.2 cycler-0.12.1 datetime-6.0 deprecated-1.3.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 multipledispatch-1.0.0 numpy-2.2.6 pandas-2.3.3 pillow-12.1.0 pykrx-1.0.51 pyparsing-3.3.1 tzdata-2025.3 wrapt-2.0.1 xlrd-2.0.2

# %%
from dotenv import load_dotenv

load_dotenv("/home/ubuntu/work/edu-src-all/.env")
#load_dotenv()
# Out:
# True

# %%
from pykrx import stock
from pykrx import bond

# %%
df = stock.get_market_ohlcv("20220720", "20220810", "005930")

# %%
df
# Out:
#                시가     고가     저가     종가       거래량       등락률
# 날짜
# 2022-07-20  61800  62100  60500  60500  16782238 -0.656814
# 2022-07-21  61100  61900  60700  61800  12291374  2.148760
# 2022-07-22  61800  62200  61200  61300  10261310 -0.809061
# 2022-07-25  60900  61900  60800  61100   9193681 -0.326264
# 2022-07-26  60800  61900  60800  61700   6597211  0.981997
# 2022-07-27  61300  61900  61200  61800   7320997  0.162075
# 2022-07-28  62300  62600  61600  61900  10745302  0.161812
# 2022-07-29  62400  62600  61300  61400  15093120 -0.807754
# 2022-08-01  61000  61700  60300  61300  13154816 -0.162866
# 2022-08-02  61200  61900  61000  61700  13614895  0.652529
# 2022-08-03  61600  61600  61000  61300  10053861 -0.648298
# 2022-08-04  61700  61800  61200  61500   9125439  0.326264
# 2022-08-05  61700  61900  61200  61500   9567620  0.000000
# 2022-08-08  61400  61400  60600  60800  11313150 -1.138211
# 2022-08-09  60600  60700  59600  60000  18251170 -1.315789
# 2022-08-10  58900  59200  58600  59100  18084349 -1.500000

# %%
from io import StringIO
csv_buffer = StringIO()
df.to_csv(csv_buffer)

csv_data = csv_buffer.getvalue()
print(csv_data)
# Out:
# 날짜,시가,고가,저가,종가,거래량,등락률
# 2022-07-20,61800,62100,60500,60500,16782238,-0.6568144499178982
# 2022-07-21,61100,61900,60700,61800,12291374,2.1487603305785123
# 2022-07-22,61800,62200,61200,61300,10261310,-0.8090614886731391
# 2022-07-25,60900,61900,60800,61100,9193681,-0.3262642740619902
# 2022-07-26,60800,61900,60800,61700,6597211,0.9819967266775778
# 2022-07-27,61300,61900,61200,61800,7320997,0.1620745542949757
# 2022-07-28,62300,62600,61600,61900,10745302,0.16181229773462785
# 2022-07-29,62400,62600,61300,61400,15093120,-0.8077544426494345
# 2022-08-01,61000,61700,60300,61300,13154816,-0.16286644951140067
# 2022-08-02,61200,61900,61000,61700,13614895,0.6525285481239804
# 2022-08-03,61600,61600,61000,61300,10053861,-0.6482982171799028
# 2022-08-04,61700,61800,61200,61500,9125439,0.3262642740619902
# 2022-08-05,61700,61900,61200,61500,9567620,0.0
# 2022-08-08,61400,61400,60600,60800,11313150,-1.1382113821138211
# 2022-08-09,60600,60700,59600,60000,18251170,-1.3157894736842104
# 2022-08-10,58900,59200,58600,59100,18084349,-1.5

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {
      "role": "system",
      "content": "다음은 삼성전자의 날짜별 주가 데이터야. 이 데이터를 분석해서 보고해줘."
    },
    {
      "role": "user",
      "content": csv_data
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 삼성전자의 주가 데이터를 분석한 결과는 다음과 같습니다.
#
# ### 1. 데이터 개요
# - **기간**: 2022년 7월 20일부터 2022년 8월 10일까지
# - **주요 지표**:
#   - **시가**: 주식이 거래된 첫 가격
#   - **고가**: 거래 기간 동안의 최고 가격
#   - **저가**: 거래 기간 동안의 최저 가격
#   - **종가**: 거래가 종료된 가격
#   - **거래량**: 해당 날짜에 거래된 주식의 수
#   - **등락률**: 전일 대비 주가의 변동 비율
#
# ### 2. 주가 변동 분석
# - **최고가**: 2022년 7월 28일, 62,600원
# - **최저가**: 2022년 8월 10일, 58,900원
# - **종가 변화**:
#   - 2022년 7월 20일: 60,500원
#   - 2022년 8월 10일: 59,100원
#   - 전체 기간 동안 종가는 약 2.3% 하락
#
# ### 3. 거래량 분석
# - **최대 거래량**: 2022년 8월 9일, 18,251,170주
# - **최소 거래량**: 2022년 7월 26일, 6,597,211주
# - 거래량은 주가의 변동성과 밀접한 관계가 있으며, 특히 8월 초에 거래량이 증가한 것을 볼 수 있습니다.
#
# ### 4. 등락률 분석
# - **가장 큰 하락률**: 2022년 8월 10일, -1.5%
# - **가장 큰 상승률**: 2022년 7월 21일, +2.15%
# - 전반적으로 하락세가 두드러지며, 특히 8월 초에 하락폭이 커졌습니다.
#
# ### 5. 결론
# - 삼성전자의 주가는 2022년 7월 20일부터 8월 10일까지 전반적으로 하락세를 보였으며, 특히 8월 초에 큰 하락폭을 기록했습니다.
# - 거래량은 주가의 변동성과 관련이 있으며, 특정 날짜에 거래량이 급증한 것을 확인할 수 있습니다.
# - 향후 주가의 회복 여부는 외부 경제 요인 및 기업 실적에 따라 달라질 것으로 예상됩니다.
#
# 이 데이터 분석을 통해 삼성전자의 주가 흐름을 이해하고, 향후 투자 결정을 내리는 데 도움이 될 수 있습니다.
