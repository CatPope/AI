# %%
# !pip install langchain-mcp-adapters langgraph langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-mcp-adapters in /home/ubuntu/.local/lib/python3.10/site-packages (0.2.1)
# Requirement already satisfied: langgraph in /home/ubuntu/.local/lib/python3.10/site-packages (1.0.7)
# Requirement already satisfied: langchain-openai in /home/ubuntu/.local/lib/python3.10/site-packages (1.1.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-mcp-adapters) (1.2.7)
# Requirement already satisfied: mcp>=1.9.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-mcp-adapters) (1.26.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-mcp-adapters) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.25.0)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (4.12.1)
# Requirement already satisfied: certifi in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (1.0.9)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (3.3)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (0.4.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-openai) (2.15.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/ubuntu/.local/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: httpx-sse>=0.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.50.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.40.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ubuntu/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp>=1.9.2->langchain-mcp-adapters) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/lib/python3/dist-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (3.4.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-mcp-adapters) (2.6.3)
# Requirement already satisfied: click>=7.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters) (8.3.1)

# %%
from dotenv import load_dotenv

load_dotenv("/home/ubuntu/work/edu-src-all/.env")
#load_dotenv()
# Out:
# True

# %%
# Create server parameters for stdio connection
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

from langchain_mcp_adapters.tools import load_mcp_tools
from langchain.agents import create_agent

from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain.agents import create_agent

from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o")

client = MultiServerMCPClient(
    {
       "busybox": {
            # make sure you start your weather server on port 8000
            "url": "http://localhost:8000/sse",
            "transport": "sse",
        }
    }
) 

agent = create_agent(model, await client.get_tools())
response = await agent.ainvoke({"messages": "/home/ubuntu/work 밑에 어떤 디렉토리들이 있지?"})

response
# Out:
# {'messages': [HumanMessage(content='/home/ubuntu/work 밑에 어떤 디렉토리들이 있지?', additional_kwargs={}, response_metadata={}, id='896c70f3-5a81-423f-b7a4-e27fdc22ac95'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 328, 'total_tokens': 346, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D39OpGIJDXS5jmfvaghRtko7ptti8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c06f8-b184-76f2-84b6-025f118a92fa-0', tool_calls=[{'name': 'ls', 'args': {'path': '/home/ubuntu/work'}, 'id': 'call_40AzA8YmERr4EnuhU6plsSox', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 328, 'output_tokens': 18, 'total_tokens': 346, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': 'Contents of /home/ubuntu/work:\nDIR  4096     arcshield_ai\nDIR  4096     edu-src-all\nDIR  4096     googletest\nDIR  4096     kosa-ai-agent-2026-1st\nDIR  4096     kosa-rag-2026-1st\nDIR  4096     onnxruntime-linux-1.20.0\nDIR  4096     onnxruntime-linux-x64-1.20.0\nFILE 6184676  onnxruntime-linux-x64-1.20.0.tgz\nDIR  4096     stable-diffusion-webui', 'id': 'lc_405ccbab-6e09-48ed-8233-085ebafb7714'}], name='ls', id='73813ff4-6b7f-4ccf-9285-838483c8f442', tool_call_id='call_40AzA8YmERr4EnuhU6plsSox', artifact={'structured_content': {'result': 'Contents of /home/ubuntu/work:\nDIR  4096     arcshield_ai\nDIR  4096     edu-src-all\nDIR  4096     googletest\nDIR  4096     kosa-ai-agent-2026-1st\nDIR  4096     kosa-rag-2026-1st\nDIR  4096     onnxruntime-linux-1.20.0\nDIR  4096     onnxruntime-linux-x64-1.20.0\nFILE 6184676  onnxruntime-linux-x64-1.20.0.tgz\nDIR  4096     stable-diffusion-webui'}}),
#   AIMessage(content='`/home/ubuntu/work` 디렉토리에는 다음과 같은 디렉토리와 파일들이 있습니다:\n\n디렉토리:\n- arcshield_ai\n- edu-src-all\n- googletest\n- kosa-ai-agent-2026-1st\n- kosa-rag-2026-1st\n- onnxruntime-linux-1.20.0\n- onnxruntime-linux-x64-1.20.0\n- stable-diffusion-webui\n\n파일:\n- onnxruntime-linux-x64-1.20.0.tgz', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 118, 'prompt_tokens': 492, 'total_tokens': 610, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-D39OrtWX6xzpCBRRJZ075nD4ohCeg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c06f8-b3e1-72e1-b2d8-adc5d17ff7fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 492, 'output_tokens': 118, 'total_tokens': 610, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
