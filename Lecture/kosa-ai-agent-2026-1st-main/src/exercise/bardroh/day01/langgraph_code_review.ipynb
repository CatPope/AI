# %%
# !pip install langgraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langgraph in /home/ubuntu/.local/lib/python3.10/site-packages (1.0.6)
# Requirement already satisfied: langchain-core>=0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: pydantic>=2.7.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.3)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain-core>=0.1->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (2.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.26.20)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.1)

# %%
import langgraph
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %%
import os

llm = ChatOpenAI(model=os.getenv("OPENAI_DEFAULT_MODEL"))

# %%
from langgraph.graph import StateGraph, START, END
from typing_extensions import TypedDict

class CodeInputs(TypedDict):
    code: str
    style_feedback: str
    bug_feedback: str
    optimization_feedback: str
    final_feedback: str

# %%
def code_style_check(inputs: CodeInputs):
    """코드 스타일 점검"""
    code = inputs["code"]
    prompt = (
        "다음 코드의 스타일을 점검하고 PEP8 준수 여부를 확인하세요:\n" + code
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    return {
        **inputs,
        "style_feedback": response.content
    }

def bug_detection(inputs: CodeInputs):
    """코드에서 버그 가능성 분석"""
    code = inputs["code"]
    prompt = (
        "다음 코드에서 잠재적인 버그나 논리적 오류를 찾아 설명하세요:\n" + code
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    return {
        **inputs,
        "bug_feedback": response.content
    }

def optimization_suggestions(inputs: CodeInputs):
    """코드 최적화 제안"""
    code = inputs["code"]
    prompt = (
        "다음 코드를 더 효율적으로 최적화할 수 있는 방법을 제안하세요:\n" + code
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    inputs["optimization_feedback"] = response.content
    return {
        **inputs,
        "optimization_feedback": response.content
    }

def aggregate_feedback(inputs):
    code = inputs["code"]
    """모든 피드백을 하나로 합쳐 반환"""
    feedback = (
        "코드 스타일 피드백:\n" + inputs["style_feedback"] + "\n\n"
        "버그 가능성 분석:\n" + inputs["bug_feedback"] + "\n\n"
        "최적화 제안:\n" + inputs["optimization_feedback"]
    )
    prompt = (
        "다음 코드와 피드백을 바탕으로 개선된 코드를 작성하세요. 반드시 코드만 출력해야 합니다.\n" + \
            "code: " + code + "\n\n" \
            "피드백: " + feedback
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    return {
        **inputs,
        "code": response.content,
        "final_feedback": feedback
    }

# %%
from langgraph.graph import END, StateGraph, START

# LangGraph 워크플로우 구축
graph = StateGraph(CodeInputs)
graph.add_node("style_check", code_style_check)
graph.add_node("bug_check", bug_detection)
graph.add_node("optimization_check", optimization_suggestions)
graph.add_node("aggregate", aggregate_feedback)

# 데이터 흐름 정의
graph.add_edge(START, "style_check")
graph.add_edge("style_check", "bug_check")
graph.add_edge("bug_check", "optimization_check")
graph.add_edge("optimization_check", "aggregate")
graph.add_edge("aggregate", END)

app = graph.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(app.get_graph(xray=True).draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
sample_code = """
def calcStats(data,  threshold=10):
    sum = 0  
    avg = 0
    for i in range(len(data)):
        sum = sum + data[i] 
    avg = sum/len(data) 

    above=[]
    for x in data:
        if x>threshold: above.append(x) 

    print ("평균:",avg)
    return {'SUM':sum, 'Average':avg, 'AboveThreshold':above}
"""
result = app.invoke({"code": sample_code})
print(result["final_feedback"])
# Out:
# 코드 스타일 피드백:
# 주어진 코드를 PEP 8 스타일 가이드에 따라 점검해보겠습니다. PEP 8은 Python 스타일 가이드로, 코드의 가독성을 높이기 위한 규칙을 제공합니다. 아래는 주석과 함께 수정 권장 사항입니다.
#
# ```python
# def calc_stats(data, threshold=10):
#     total_sum = 0   # 'sum'은 내장 함수 이름과 동일하므로 더 구체적인 이름 사용
#     avg = 0
#     for i in range(len(data)):
#         total_sum += data[i]  # 더 간결한 방법으로 수정
#     avg = total_sum / len(data)  # 변수 이름도 더 적절하게 변경
#
#     above = []  # 공백을 넣어 가독성 향상
#     for x in data:
#         if x > threshold:
#             above.append(x)  # 조건문에 따라서 명확한 출력
#
#     print("평균:", avg)  # 공백 정렬 및 불필요한 공백 제거
#     return {'SUM': total_sum, 'Average': avg, 'AboveThreshold': above}  # 변수 이름 통일성과 일관성 유지
# ```
#
# ### PEP 8 준수 여부 및 수정 사항
# 1. **함수명**: 함수명을 snake_case 스타일(`calc_stats`)로 변경했습니다.
# 2. **변수명**: 변수명인 `sum`을 `total_sum`으로 변경했습니다. `sum`은 내장 함수의 이름이므로 이를 피하는 것이 좋습니다.
# 3. **가독성 개선**:
#    - `total_sum = total_sum + data[i]`는 `total_sum += data[i]`로 간단히 표현할 수 있습니다.
#    - 리스트 초기화를 위한 줄을 공백을 추가하여 가독성을 높였습니다.
#    - `if` 문과 `append` 코드 블록 사이에 항상 공백을 추가하는 것이 좋습니다.
# 4. **출력문**: `print` 함수 안의 부모heses 앞뒤에 불필요한 공백이 있었으므로 이를 제거했습니다.
# 5. **상수 정의**: 가능하다면 상수 변수를 정의하고 사용하는 것이 바람직합니다. (예: `THRESHOLD = 10`)
# 6. **예외 처리**: 입력 데이터가 비어 있을 경우에 대한 예외 처리가 추가될 수 있습니다.
#
# 위와 같이 수정된 코드 스타일은 Pythonic하며 PEP 8 스타일 가이드를 더 잘 준수합니다. 필요한 경우 예외 처리를 추가하여 더욱 견고한 코드를 만들 수 있습니다.
#
# 버그 가능성 분석:
# 제시된 코드에서는 몇 가지 잠재적인 버그나 논리적 오류가 있습니다. 아래에 이들을 설명하겠습니다:
#
# 1. **변수 이름 'sum' 사용**:
#     - `sum`이라는 변수를 사용하고 있습니다. 하지만 `sum`은 내장 함수의 이름이기도 하므로, 이를 사용하면 내장 함수인 `sum`을 덮어쓰게 됩니다. 이는 나중에 코드를 읽거나 수정할 때 혼란을 일으킬 수 있으며, 코드의 다른 부분에서 `sum()` 함수를 사용하지 못하게 만들 수 있습니다. 대신 `total`, `total_sum`과 같은 다른 이름을 사용하는 것이 좋습니다.
#
# 2. **빈 리스트 처리**:
#     - `data`가 비어 있는 경우 (예: `data = []`) 함수를 호출하면 `len(data)`가 0이 되어 `avg = sum/len(data)`에서 ZeroDivisionError가 발생할 수 있습니다. 따라서 `data`가 비어 있는 경우를 처리해 주어야 합니다.
#
# 3. **평균 계산 전 리스트 길이 확인**:
#     - 평균 계산을 하기 전에 `data`의 길이가 0인지 확인하는 로직이 있으면 좋습니다. 이를 통해 ZeroDivisionError를 방지할 수 있습니다. 예를 들어, 다음과 같이 처리할 수 있습니다:
#
#     ```python
#     if len(data) == 0:
#         return {'SUM': 0, 'Average': 0, 'AboveThreshold': []}
#     ```
#
# 4. **threshold 비교의 유연성**:
#     - 현재는 threshold가 항상 고정된 값(10)으로 설정되어 있지만, 이를 함수 인자에서 받아들이는 것은 좋습니다. 이미 그렇게 하고 있지만, 더 명시적으로 정보를 제공하기 위해 threshold가 유효한 값인지 확인하는 로직이 추가될 수 있습니다.
#
# 5. **출력의 언어**:
#     - `print("평균:", avg)`에서 출력 내용이 한국어로 되어 있는데, 이를 개발 환경에 따라 일관성 있게 유지할 필요가 있습니다. 특히 다국적 팀에서 작업할 경우 영어 메시지를 사용하는 것이 좋습니다.
#
# 수정된 코드는 다음과 같이 작성될 수 있습니다:
#
# ```python
# def calcStats(data, threshold=10):
#     if len(data) == 0:
#         return {'SUM': 0, 'Average': 0, 'AboveThreshold': []}
#
#     total_sum = 0
#     for i in range(len(data)):
#         total_sum += data[i]
#     avg = total_sum / len(data)
#
#     above = [x for x in data if x > threshold]
#
#     print("Average:", avg)
#     return {'SUM': total_sum, 'Average': avg, 'AboveThreshold': above}
# ```
#
# 위와 같이 코드를 수정하면 오류를 줄일 수 있고 가독성을 높일 수 있습니다.
#
# 최적화 제안:
# 주어진 `calcStats` 함수를 보다 효율적으로 최적화하기 위해 몇 가지 개선 사항을 적용할 수 있습니다. 주요 목표는 반복문을 줄이고 한 번의 반복으로 모든 계산을 수행하는 것입니다. 이를 위해 `sum`과 `avg`를 한 번의 루프에서 동시에 계산하고, `above` 리스트도 동시에 생성할 수 있습니다.
#
# 아래 코드는 이러한 방안을 적용한 예제입니다.
#
# ```python
# def calcStats(data, threshold=10):
#     total_sum = 0
#     above = []
#
#     # 데이터 길이를 한 번만 계산
#     n = len(data)
#
#     for x in data:
#         total_sum += x
#         if x > threshold:
#             above.append(x)
#
#     avg = total_sum / n if n > 0 else 0  # 데이터가 없는 경우에 대비
#
#     print("평균:", avg)
#     return {'SUM': total_sum, 'Average': avg, 'AboveThreshold': above}
#
# # 예시 데이터
# data = [5, 12, 18, 7, 25]
# result = calcStats(data, threshold=10)
# print(result)
# ```
#
# ### 변경 사항 설명:
#
# 1. **루프 통합**: `sum`을 계산하고 동시에 `above` 리스트를 생성하기 위해 `data`를 한 번만 순회하도록 변경했습니다. 이렇게 하면 O(n)의 성능이 유지되며 불필요한 반복을 줄일 수 있습니다.
#
# 2. **변수명 변경**: `sum`이라는 이름은 내장 함수와 충돌할 수 있으므로 `total_sum`으로 변경했습니다.
#
# 3. **예외 처리**: 데이터가 비어 있을 때 평균을 계산할 때 0으로 나누는 경우를 방지하기 위해 조건문을 추가했습니다.
#
# 이러한 개선을 통해 코드의 효율성과 가독성을 높일 수 있습니다.

# %%
print(result["code"])
# Out:
# ```python
# def calc_stats(data, threshold=10):
#     if len(data) == 0:
#         return {'SUM': 0, 'Average': 0, 'AboveThreshold': []}
#
#     total_sum = 0
#     above = []
#     n = len(data)
#
#     for x in data:
#         total_sum += x
#         if x > threshold:
#             above.append(x)
#
#     avg = total_sum / n
#
#     print("평균:", avg)
#     return {'SUM': total_sum, 'Average': avg, 'AboveThreshold': above}
# ```
