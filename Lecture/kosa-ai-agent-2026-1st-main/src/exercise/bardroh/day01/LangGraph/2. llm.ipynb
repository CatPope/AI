# %%
# !pip install langgraph langchain_openai langchain_core
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langgraph in /home/ubuntu/.local/lib/python3.10/site-packages (1.0.6)
# Requirement already satisfied: langchain_openai in /home/ubuntu/.local/lib/python3.10/site-packages (1.1.7)
# Requirement already satisfied: langchain_core in /home/ubuntu/.local/lib/python3.10/site-packages (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: pydantic>=2.7.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_openai) (1.109.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langchain_core) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (2.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.0)
# Requirement already satisfied: certifi in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /home/ubuntu/.local/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.6.3)

# %%
import os
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model=os.getenv("OPENAI_DEFAULT_MODEL"))

# %%
def call_llm(message):
    return llm.invoke(message)

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(object)
# Add the nodes
workflow.add_node("call_llm", call_llm)

# Add the Edges
workflow.add_edge(START, "call_llm")
workflow.add_edge("call_llm", END)

#Compile the workflow
app = workflow.compile()

# %%
from IPython.display import Image, display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
response = app.invoke("안녕?")
print(response.content)
# Out:
# 안녕하세요! 어떻게 도와드릴까요?
